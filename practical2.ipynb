# %%
import pandas as pd
import numpy as np
d = pd.read_csv('StudentsPerformance.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1968\2004989897.py in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 d = pd.read_csv('StudentsPerformance.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
d.isnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False           True           True            False           False
# 6        False          False          False             True           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
d.notnull()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True          False          False             True            True
# 6         True           True           True            False            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
d.dropna()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0         72.0           88.0           62.0             88.0            2021
# 1         78.0           87.0           64.0             76.0            2019
# 2         71.0           20.0           75.0             76.0            2019
# 3         62.0           75.0           73.0             82.0            2019
# 4         79.0           78.0           65.0             98.0            2021
# 7         63.0           76.0           78.0             96.0            2020
# 8        100.0           79.0           77.0             77.0            2019
# 9         68.0           81.0           67.0             98.0            2021
# 10        62.0           77.0           62.0             95.0            2019
# 11        60.0           81.0           76.0             93.0            2018
# 12        63.0           92.0           80.0             82.0            2021
# ...

# %%
d.fillna(999)
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0         72.0           88.0           62.0             88.0            2021
# 1         78.0           87.0           64.0             76.0            2019
# 2         71.0           20.0           75.0             76.0            2019
# 3         62.0           75.0           73.0             82.0            2019
# 4         79.0           78.0           65.0             98.0            2021
# 5         64.0          999.0          999.0             83.0            2021
# 6         63.0           80.0           77.0            999.0            2020
# 7         63.0           76.0           78.0             96.0            2020
# 8        100.0           79.0           77.0             77.0            2019
# 9         68.0           81.0           67.0             98.0            2021
# 10        62.0           77.0           62.0             95.0            2019
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
d['Gender'] =le.fit_transform(d['Gender'])

# %%
d
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0         72.0           88.0           62.0             88.0            2021
# 1         78.0           87.0           64.0             76.0            2019
# 2         71.0           20.0           75.0             76.0            2019
# 3         62.0           75.0           73.0             82.0            2019
# 4         79.0           78.0           65.0             98.0            2021
# 5         64.0            NaN            NaN             83.0            2021
# 6         63.0           80.0           77.0              NaN            2020
# 7         63.0           76.0           78.0             96.0            2020
# 8        100.0           79.0           77.0             77.0            2019
# 9         68.0           81.0           67.0             98.0            2021
# 10        62.0           77.0           62.0             95.0            2019
# ...

# %%
x = d['Math_Score'].mean()
d['Math_Score']=d['Math_Score'].fillna(x)

# %%
d
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_join_date  \
# 0    72.000000           88.0           62.0             88.0            2021
# 1    78.000000           87.0           64.0             76.0            2019
# 2    71.000000           20.0           75.0             76.0            2019
# 3    62.000000           75.0           73.0             82.0            2019
# 4    79.000000           78.0           65.0             98.0            2021
# 5    64.000000            NaN            NaN             83.0            2021
# 6    63.000000           80.0           77.0              NaN            2020
# 7    63.000000           76.0           78.0             96.0            2020
# 8   100.000000           79.0           77.0             77.0            2019
# 9    68.000000           81.0           67.0             98.0            2021
# 10   62.000000           77.0           62.0             95.0            2019
# ...

# %%
d[['Reading_Score']].isnull().sum()
# Out:
# Reading_Score    2
# dtype: int64

# %%
col = ['Math_Score','Reading_Score','Writing_Score','Placement_Score']
d.boxplot(col)
# Out:
# <AxesSubplot:>

# %%
print(np.where(d['Math_Score']>90))
# Out:
# (array([ 8, 23], dtype=int64),)

# %%
d.iloc[[8],[0]]
# Out:
#    Math_Score
# 8       100.0

# %%
print(np.where(d['Reading_Score']<30))
# Out:
# (array([2], dtype=int64),)

# %%
d.iloc[[2],[1]]
# Out:
#    Reading_Score
# 2           20.0

# %%
import matplotlib.pyplot as plt
plt.scatter(d['Reading_Score'],d['Reading_Score'] )

# %%
plt.show()

# %%
from scipy import stats
z = np.abs(stats.zscore(d['Math_Score']))
print(z)
# Out:
# 0     0.066884
# 1     0.555430
# 2     0.014540
# 3     0.747359
# 4     0.636855
# 5     0.584510
# 6     0.665935
# 7     0.665935
# 8     2.346766
# 9     0.258813
# 10    0.747359
# 11    0.910208
# 12    0.665935
# 13    0.000000
# 14    0.148309
# 15    0.584510
# 16    0.910208
# 17    0.584510
# 18    0.177389
# 19    0.066884
# 20    0.503086
# 21    0.095964
# 22    0.311157
# 23    3.975253
# 24    0.636855
# 25    0.311157
# 26    0.828784
# 27    0.229733
# 28    0.340237
# Name: Math_Score, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(d['placement_score'], d['placement_offer_count'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1968\3509037893.py in <module>
# ----> 1 fig, ax = plt.subplots(figsize = (18,10))
#       2 ax.scatter(d['placement_score'], d['placement_offer_count'])
#       3 plt.show()
#
# NameError: name 'plt' is not defined
